# %% [markdown]
# <a href="https://colab.research.google.com/github/NadezhdaMalysheva/projects/blob/main/hyperparameters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import matplotlib.pyplot as plt
import seaborn as sns # advanced vizs

# %%
df = pd.read_csv('/content/drive/MyDrive/Научная работа/Спецсем/TabNet /hyperparameters.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Datasets          17 non-null     object
#  1   Rows              14 non-null     float64
#  2   Columns           14 non-null     float64
#  3   Task              17 non-null     int64
#  4   Nd                17 non-null     int64
#  5   Nd=Na             17 non-null     int64
#  6   B                 17 non-null     int64
#  7   BV                17 non-null     int64
#  8   mB                17 non-null     float64
#  9   λsparse           17 non-null     float64
#  10  Nsteps            17 non-null     int64
#  11  γ                 17 non-null     float64
#  12  learning rate     17 non-null     object
#  13  decay rate        17 non-null     float64
#  14  decay iterations  17 non-null     int64
#  15  iterations        17 non-null     int64
# ...

# %%
df = df.rename({'Nd=Na':'Na'}, axis=1)

# %%
corr = df.corr()
plt.figure(figsize = (10, 8))
sns.heatmap(corr, annot = True)

# %% [markdown]
# Корреляции :
#
#
# *   Rows
#   * decay iterations
#   * iterations
#   * Nsteps
#   * B
#   * Nd
#
# *   Columns
#   * Na
#   * B
#   * Nd
# *   Task
#   * BV

# %%
sns.pairplot(data = df, palette = 'Dark2', hue = 'Rows')

# %%
sns.pairplot(data = df, palette = 'Dark2', hue = 'Columns')

# %%
sns.pairplot(data = df, palette = 'Dark2', hue = 'Task')

# %%
sns.lmplot(x = 'Task', y = 'BV', data = df)
sns.lmplot(x = 'Rows', y = 'decay iterations', data = df)
sns.lmplot(x = 'Rows', y = 'iterations', data = df)
sns.lmplot(x = 'Rows', y = 'Nsteps', data = df)
sns.lmplot(x = 'Rows', y = 'B', data = df)
sns.lmplot(x = 'Rows', y = 'Nd', data = df)
sns.lmplot(x = 'Columns', y = 'Na', data = df)
sns.lmplot(x = 'Columns', y = 'B', data = df)
sns.lmplot(x = 'Columns', y = 'Nd', data = df)
sns.lmplot(x = 'γ', y = 'λsparse', data = df)
sns.lmplot(x = 'Nd', y = 'Nsteps', data = df)
#sns.lmplot(x = 'Task', y = 'Nsteps', data = df)

# %%
sns.lmplot(x = 'plate', y='mjd', data = df, hue='class', col = 'class', palette='Set1', scatter_kws= {'edgecolor':'white', 'alpha':0.8, 'linewidths': 0.5})
sns.lmplot(x = 'i', y='z', data = df, hue='class', col = 'class', palette='magma', scatter_kws= {'edgecolor':'white', 'alpha':0.8, 'linewidths': 0.5})
sns.lmplot(x = 'r', y='g', data = df, hue='class', col = 'class', palette='Dark2', scatter_kws= {'edgecolor':'white', 'alpha':0.8, 'linewidths': 0.5})

# %%
df
# Out:
#                Datasets        Rows  Columns  ...  shared   decision  size
# 0                  Syn1     10000.0     11.0  ...        2         2   NaN
# 1                  Syn2     10000.0     11.0  ...        2         2   NaN
# 2                  Syn3     10000.0     11.0  ...        2         2   NaN
# 3                  Syn4     10000.0     11.0  ...        2         2   NaN
# 4                  Syn5     10000.0     11.0  ...        2         2   NaN
# 5                  Syn6     10000.0     11.0  ...        2         2   NaN
# 6     Forest Cover Type    581000.0     54.0  ...        2         2   NaN
# 7           Poker Hands   1025010.0     11.0  ...        2         2   NaN
# 8              Sarcos S         NaN      NaN  ...        1         2     S
# 9              Sarcos M         NaN      NaN  ...        2         2     M
# 10             Sarcos L         NaN      NaN  ...        2         2     L
# 11              Higgs S  11000000.0     28.0  ...        2         2    S
# ...
