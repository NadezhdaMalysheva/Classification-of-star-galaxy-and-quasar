# %%
График recall для подклассов:

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.offline as py
color = sns.color_palette()
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
import plotly.tools as tls

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score 
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
import joblib
from tqdm.notebook import tqdm

# %% [markdown]
# # Подготовка данных

# %%
df = pd.read_csv('./input/specphotoall.csv') 

df.head()
# Out:
#                  objID         ra       dec         z      zErr   class  \
# 0  1237679341106758387  37.470142 -5.554778  0.785255  0.000138  GALAXY
# 1  1237679341106757929  37.431501 -5.600435  1.285837  3.473993     QSO
# 2  1237679341106758149  37.388988 -5.556329  0.779955  0.000054  GALAXY
# 3  1237679440426172681  37.327114 -5.485252  0.714883  0.000028  GALAXY
# 4  1237679341106692861  37.315868 -5.519308  0.316563  0.000031  GALAXY
#
#   subClass  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  cModelMag_u  \
# 0      NaN  23.38412  23.00183  22.67571  21.95927  21.39581     20.01718
# 1      NaN  22.52914  23.78679  23.21358  22.17294  21.80350     21.23949
# 2      NaN  25.44541  23.13342  23.57675  24.34838  22.31492     20.38550
# 3      NaN  25.43466  23.13782  23.31316  22.53812  22.60905     25.45580
# 4      NaN  23.17536  21.34756  20.35171  20.05924  19.64511     21.14052
#
#    cModelMag_g  cModelMag_r  cModelMag_i  cModelMag_z
# 0     21.90474     21.99600     21.05722     20.29795
# 1     20.26025     22.12909     21.14929     20.66354
# 2     22.09762     23.74675     24.19759     20.62257
# 3     22.96513     23.37321     22.59266     22.64923
# 4     20.62957     19.60872     19.07587     18.90757

# %%
df.shape
# Out:
# (5241919, 17)

# %%
df[df['objID'] == 1237648720142401611]
# Out:
#                       objID         ra       dec         z      zErr   class  \
# 953960  1237648720142401611  146.71421 -1.041304  0.021275  0.000009  GALAXY
# 953961  1237648720142401611  146.71421 -1.041304  0.021222  0.000009  GALAXY
#
#            subClass  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  \
# 953960          NaN  19.08621  17.41779  16.59581  16.03497  15.68077
# 953961  STARFORMING  19.08621  17.41779  16.59581  16.03497  15.68077
#
#         cModelMag_u  cModelMag_g  cModelMag_r  cModelMag_i  cModelMag_z
# 953960     16.81934     15.38817     14.67877     14.25035     13.97063
# 953961     16.81934     15.38817     14.67877     14.25035     13.97063

# %%
df = df.drop_duplicates('objID', keep = 'last')

# %%
df[df['objID'] == 1237648720142401611]
# Out:
#                       objID         ra       dec         z      zErr   class  \
# 953961  1237648720142401611  146.71421 -1.041304  0.021222  0.000009  GALAXY
#
#            subClass  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  \
# 953961  STARFORMING  19.08621  17.41779  16.59581  16.03497  15.68077
#
#         cModelMag_u  cModelMag_g  cModelMag_r  cModelMag_i  cModelMag_z
# 953961     16.81934     15.38817     14.67877     14.25035     13.97063

# %%
df3 = df.copy()
labels = {'STAR':1, 'GALAXY':2, 'QSO':3}
df.replace({'class':labels}, inplace = True)
df.head()
# Out:
#                  objID         ra       dec         z      zErr  class  \
# 0  1237679341106758387  37.470142 -5.554778  0.785255  0.000138      2
# 1  1237679341106757929  37.431501 -5.600435  1.285837  3.473993      3
# 2  1237679341106758149  37.388988 -5.556329  0.779955  0.000054      2
# 3  1237679440426172681  37.327114 -5.485252  0.714883  0.000028      2
# 4  1237679341106692861  37.315868 -5.519308  0.316563  0.000031      2
#
#   subClass  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  cModelMag_u  \
# 0      NaN  23.38412  23.00183  22.67571  21.95927  21.39581     20.01718
# 1      NaN  22.52914  23.78679  23.21358  22.17294  21.80350     21.23949
# 2      NaN  25.44541  23.13342  23.57675  24.34838  22.31492     20.38550
# 3      NaN  25.43466  23.13782  23.31316  22.53812  22.60905     25.45580
# 4      NaN  23.17536  21.34756  20.35171  20.05924  19.64511     21.14052
#
#    cModelMag_g  cModelMag_r  cModelMag_i  cModelMag_z
# 0     21.90474     21.99600     21.05722     20.29795
# 1     20.26025     22.12909     21.14929     20.66354
# 2     22.09762     23.74675     24.19759     20.62257
# 3     22.96513     23.37321     22.59266     22.64923
# 4     20.62957     19.60872     19.07587     18.90757

# %%
df2 = df3.copy()
labels = {'STAR':0, 'GALAXY':1, 'QSO':1}
df2.replace({'class':labels}, inplace = True)
df2.head()
# Out:
#                  objID         ra       dec         z      zErr  class  \
# 0  1237679341106758387  37.470142 -5.554778  0.785255  0.000138      1
# 1  1237679341106757929  37.431501 -5.600435  1.285837  3.473993      1
# 2  1237679341106758149  37.388988 -5.556329  0.779955  0.000054      1
# 3  1237679440426172681  37.327114 -5.485252  0.714883  0.000028      1
# 4  1237679341106692861  37.315868 -5.519308  0.316563  0.000031      1
#
#   subClass  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  cModelMag_u  \
# 0      NaN  23.38412  23.00183  22.67571  21.95927  21.39581     20.01718
# 1      NaN  22.52914  23.78679  23.21358  22.17294  21.80350     21.23949
# 2      NaN  25.44541  23.13342  23.57675  24.34838  22.31492     20.38550
# 3      NaN  25.43466  23.13782  23.31316  22.53812  22.60905     25.45580
# 4      NaN  23.17536  21.34756  20.35171  20.05924  19.64511     21.14052
#
#    cModelMag_g  cModelMag_r  cModelMag_i  cModelMag_z
# 0     21.90474     21.99600     21.05722     20.29795
# 1     20.26025     22.12909     21.14929     20.66354
# 2     22.09762     23.74675     24.19759     20.62257
# 3     22.96513     23.37321     22.59266     22.64923
# 4     20.62957     19.60872     19.07587     18.90757

# %%
X =  df.drop(['class','subClass', 'objID', 'z', 'zErr', 'ra', 'dec'], axis = 1).values
y = df['class'].values
X.shape
# Out:
# (4614588, 10)

# %%
X2 = df2.drop(['class','subClass', 'objID', 'z', 'zErr', 'ra', 'dec'], axis = 1).values
y2 = df2['class'].values
X2.shape
# Out:
# (4614588, 10)

# %%
def data_preparation(X, y, test_size = 0.8, binar=True): #бработка данных для классификаторов (бинарных и нет)
    if binar:
        count = np.min(((y==1).sum(), (y==0).sum()))
        ind1 = np.random.choice((y==0).sum(), size=count, replace=False)
        ind3 = np.random.choice((y==1).sum(), size=count, replace=False)

        X1_train, X1_test, y1_train, y1_test = train_test_split(X[y==0][ind1], y[y==0][ind1], test_size=test_size, random_state = 43)
        X3_train, X3_test, y3_train, y3_test = train_test_split(X[y==1][ind3], y[y==1][ind3], test_size=test_size, random_state = 43)

        X_train, X_test = np.concatenate((X1_train, X3_train)), np.concatenate((X1_test, X3_test))
        y_train, y_test = np.concatenate((y1_train, y3_train)), np.concatenate((y1_test, y3_test))

    else:
        count = np.min(((y==1).sum(), (y==2).sum(), (y==3).sum()))
        ind1 = np.random.choice((y==1).sum(), size=min(count*2, (y==1).sum()), replace=False)
        ind2 = np.random.choice((y==2).sum(), size=count, replace=False)
        ind3 = np.random.choice((y==3).sum(), size=count, replace=False)
        X_train, X_test, y_train, y_test = train_test_split(np.concatenate((X[y==1][ind1], X[y==2][ind2], X[y==3][ind3])), np.concatenate((y[y==1][ind1], y[y==2][ind2], y[y==3][ind3])), test_size = 0.9, random_state = 42)
        
    X_test_not_scaling = X_test.copy()
    X_train_not_scaling = X_train.copy()

    robust = RobustScaler()

    X_train = robust.fit_transform(X_train)
    X_test = robust.transform(X_test)

    return X_train, X_test, y_train, y_test, X_test_not_scaling, X_train_not_scaling

# %%
X_train, X_test, y_train, y_test, X_test_not_scaling, X_train_not_scaling = data_preparation(X, y, binar=False)

# %%
X2_train, X2_test, y2_train, y2_test, X2_test_not_scaling, X2_train_not_scaling = data_preparation(X2, y2)

# %%
from sklearn.manifold import TSNE
idx = np.random.permutation(3000)
x_tmp = TSNE(2).fit_transform(X_test[0:3000])
x_tmp = x_tmp[idx]
y_tmp = y_test[:3000][idx]

# %%
import seaborn as sns

# %%
aaa = (y_tmp != 2)
x_aaa = x_tmp[aaa]
y_aaa = y_tmp[aaa]

# %%
sns.scatterplot(x=x_tmp[:, 0], y=x_tmp[:, 1], hue=y_tmp)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=x_aaa[:, 0], y=x_aaa[:, 1], hue=y_aaa)
# Out:
# <AxesSubplot:>

# %%
print(X2_train.shape, X2_test.shape, y2_train.shape, y2_test.shape)
# Out:
# (384144, 10) (1536582, 10) (384144,) (1536582,)

# %%
#переменные для разделения выборки по признаку cModelMag_r:
n = 30

def print_plot(ml, X_test, y_test, X_test_not_scaling, binar=True):
    #функция построения графика зависимости метрик классификации от r
    m = 15
    N = (X_test_not_scaling[:,7].max() - m) / n
    precision = []
    recall = []
    f1 = []
    r_mean = []
    sup = []
    #y_pred_all = ml.predict(X_test)

    for i in tqdm(range(0, n)):
        indx = (X_test_not_scaling[:,7] >= (m + N * i)) & (X_test_not_scaling[:,7] <= (m + N * (i + 1))) #создаем выборку с необходимым нам диапазоном r
        X = X_test[indx]
        y = y_test[indx]
        coun = (1-binar)*np.min(((y == 3).sum(), (y == 1).sum(), (y == 2).sum())) + binar*np.min(((y == 0).sum(), (y == 1).sum()))
        if coun > 700: #не будем брать слишком маленькие выборки
            
            ind1 = np.random.choice((y==1).sum(), size=coun, replace=False)
            if binar:
                ind0 = np.random.choice((y==0).sum(), size=coun, replace=False)
                X = np.concatenate((X[y==0][ind0], X[y==1][ind1]))
                y = np.concatenate((np.zeros(coun), np.ones(coun))) 
                star = '0.0'
            else:
                ind2 = np.random.choice((y==2).sum(), size=coun, replace=False)
                ind3 = np.random.choice((y==3).sum(), size=coun, replace=False)
                X = np.concatenate((X[y==1][ind1], X[y==2][ind2], X[y==3][ind3]))
                y = np.concatenate((np.ones(coun), np.ones(coun)*2, np.ones(coun)*3))
                star = '1.0'
                
            h = classification_report(y, ml.predict(X), output_dict=True, zero_division=0)
            #print(h)
            
            precision.append(h[star]['precision'])
            recall.append(h[star]['recall'])
            f1.append(h[star]['f1-score'])
            sup.append((h[star]['support'], h['1.0']['support']))
            r_mean.append(X_test_not_scaling[indx][:,7].mean())
         
    plt.figure(figsize = (5,4))
    plt.title('Зависимость precision от признкака cModelMag_r:')
    plt.plot(r_mean, precision, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
    plt.figure(figsize = (5,4))
    plt.title('Зависимость recall от признкака cModelMag_r:')
    plt.plot(r_mean, recall, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
    plt.figure(figsize = (5,4))
    plt.title('Зависимость f1 от признкака cModelMag_r:')
    plt.plot(r_mean, f1, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
    
    print(sup)
    #indx = df['cModelMag_r'] < 15
    #indx1 = df['cModelMag_r'] < 18 & df['cModelMag_r'] > 16
    #return classification_report(y[indx], y_pred_all[indx], output_dict=True, zero_division=0)['1']['precision'],

# %%
def roc(model, X_test, y_test, lab):
    from sklearn.metrics import roc_curve
    sns.set(font_scale=1.5)
    sns.set_color_codes("muted")

    plt.figure(figsize=(10, 8))
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:,1], pos_label=lab)
    lw = 2
    plt.plot(fpr, tpr, lw=lw, label='ROC curve ')
    plt.plot([0, 1], [0, 1])
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve')
    plt.savefig("ROC.png")
    plt.show()

# %%
import time
t = time.time()
#rf = RandomForestClassifier(n_estimators=200, random_state=42, max_features=5, min_samples_leaf=1) 
#rf.fit(X_train, y_train)
rf = joblib.load('rf_new.pkl')
y_pred = rf.predict(X_test)
print('Classification Report: \n', classification_report(y_test, y_pred))
print('Confusion Matrix: \n', confusion_matrix(y_test, y_pred))
rf_train_acc = rf.score(X_train, y_train)
print('Training Score: ', rf_train_acc)
rf_test_acc = rf.score(X_test, y_test)
print('Testing Score: ', rf_test_acc)
print(-t + time.time())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-2d793f98b796> in <module>
#       4 #rf.fit(X_train, y_train)
#       5 rf = joblib.load('rf_new.pkl')
# ----> 6 y_pred = rf.predict(X_test)
#       7 print('Classification Report: \n', classification_report(y_test, y_pred))
#       8 print('Confusion Matrix: \n', confusion_matrix(y_test, y_pred))
#
# ~/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# ~/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     680                      for j in np.atleast_1d(self.n_classes_)]
#     681         lock = threading.Lock()
# --> 682         Parallel(n_jobs=n_jobs, verbose=self.verbose,
#     683                  **_joblib_parallel_args(require="sharedmem"))(
#     684             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1030                 self._iterating = self._original_iterator is not None
#    1031
# -> 1032             while self.dispatch_one_batch(iterator):
#    1033                 pass
#    1034
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     845                 return False
#     846             else:
# --> 847                 self._dispatch(tasks)
#     848                 return True
#     849
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     763         with self._lock:
#     764             job_idx = len(self._jobs)
# --> 765             job = self._backend.apply_async(batch, callback=cb)
#     766             # A job can complete so quickly than its callback is
#     767             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.local/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~/.local/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     250         # change the default number of processes to -1
#     251         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 252             return [func(*args, **kwargs)
#     253                     for func, args, kwargs in self.items]
#     254
#
# ~/.local/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _accumulate_prediction(predict, X, out, lock)
#     464     complains that it cannot pickle it when placed there.
#     465     """
# --> 466     prediction = predict(X, check_input=False)
#     467     with lock:
#     468         if len(out) == 1:
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_classes.py in predict_proba(self, X, check_input)
#     921         check_is_fitted(self)
#     922         X = self._validate_X_predict(X, check_input)
# --> 923         proba = self.tree_.predict(X)
#     924
#     925         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
rf.feature_importances_

# %%
print_plot(rf, X_test, y_test, X_test_not_scaling, binar=False)

# %%
joblib.dump(rf, 'rf_new.pkl')
#rf = rf = joblib.load('rf_new.pkl')
# Out:
# ['rf_new.pkl']

# %%
roc(rf, X_test, y_test, 2)

# %%
rf2 = RandomForestClassifier(n_estimators=200, random_state=42, max_features=3, min_samples_leaf=1) 
rf2.fit(X2_train, y2_train)
#joblib.dump(rf2, 'rf2.pkl')
#rf2 = joblib.load('rf2_new.pkl')
y2_pred = rf2.predict(X2_test)
print('Classification Report: \n', classification_report(y2_test, y2_pred))
print('Confusion Matrix: \n', confusion_matrix(y2_test, y2_pred))
rf2_train_acc = rf2.score(X2_train, y2_train)
print('Training Score: ', rf2_train_acc)
rf2_test_acc = rf2.score(X2_test, y2_test)
print('Testing Score: ', rf2_test_acc)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94    768291
#            1       0.95      0.93      0.94    768291
#
#     accuracy                           0.94   1536582
#    macro avg       0.94      0.94      0.94   1536582
# weighted avg       0.94      0.94      0.94   1536582
#
# Confusion Matrix:
#  [[728075  40216]
#  [ 50477 717814]]
# Training Score:  1.0
# Testing Score:  0.9409774421410637

# %%
rf2 = joblib.load('rf2_new.pkl')

# %%
rf2.feature_importances_
# Out:
# array([0.10695768, 0.16376902, 0.12027851, 0.10082805, 0.12865486,
#        0.06917801, 0.06231376, 0.09330021, 0.08480868, 0.06991121])

# %%
print_plot(rf2, X2_test, y2_test, X2_test_not_scaling)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=30.0), HTML(value='')))
# [(4534, 4534), (8758, 8758), (19034, 19034), (34933, 34933), (64585, 64585), (39790, 39790), (30090, 30090), (44419, 44419), (53571, 53571), (61578, 61578), (70204, 70204), (72042, 72042), (53791, 53791), (21066, 21066), (6865, 6865), (2536, 2536), (730, 730)]

# %% [markdown]
#  Точность увеличивается для более слабых объектов, что кажется неправдоподобным

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y2_test, rf2.predict(X2_test), drop_intermediate=False)
#fpr, tpr, thresholds = roc_curve(y2_test, rf2.predict(X2_test))
auc = auc(fpr, tpr)
print('auc =', auc)

plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b',
label='AUC = %0.10f'% auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# auc = 0.9413750779327104

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt

disp = plot_precision_recall_curve(rf2, X2_test, y2_test)
disp.ax_.set_title('2-class Precision-Recall')
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall')

# %%
joblib.dump(rf2, 'rf2_new.pkl')
# Out:
# ['rf2_new.pkl']

# %% [markdown]
# roc и precision-recall кривые для объектов с плохой точностью:

# %%
index = (df['cModelMag_r'] < 22.5) & (df['cModelMag_r'] > 21)
X_train_rf, X_test_rf, y_train_rf, y_test_rf, X_test_not_scaling_rf, X_train_not_scaling_rf = data_preparation(X2[index], y2[index], test_size=0.8)

# %%
from sklearn.metrics import roc_curve, auc
y_pred_rf = rf2.predict_proba(X_test_rf)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test_rf, y_pred_rf, drop_intermediate=False)
#fpr, tpr, thresholds = roc_curve(y2_test, rf2.predict(X2_test))
auc = auc(fpr, tpr)
print('auc =', auc)

plt.figure()
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b',
label='AUC = %0.10f'% auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# auc = 0.73500942751299

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import plot_precision_recall_curve
import matplotlib.pyplot as plt

disp = plot_precision_recall_curve(rf2, X_test_rf, y_test_rf)
disp.ax_.set_title('2-class Precision-Recall')
# Out:
# Text(0.5, 1.0, '2-class Precision-Recall')

# %% [markdown]
# # Функции для подбора параметров классификаторов

# %%
def visualize(test_metric_acc, train_metric_acc, test_metric_f1, train_metric_f1, grid, xlabel ='X'):
        train_acc, tast_acc = np.asarray(train_metric_acc), np.asarray(test_metric_acc)
        train_f1, test_f1 = np.asarray(train_metric_f1), np.asarray(test_metric_f1)
        print("Best accuracy_store is", max(test_acc), "with",
                                    grid[np.argmax(test_acc)], xlabel)
        plt.style.use('ggplot')
        plt.figure(figsize=(16, 8))
        plt.title("Accuracy")
        plt.plot(grid, test_acc, label="test")
        plt.plot(grid, train_acc, label="train")
        plt.xlabel(xlabel)
        plt.legend()
        plt.show()
                  
        print("Лучший f1_score ", max(test_f1), "with",
                                    grid[np.argmax(test_f1)],  xlabel)
        plt.style.use('ggplot')
        plt. figure(figsize=(16, 8))
        plt.title("F1_score")
        plt.plot(grid, test_f1, label="test")
        plt.plot(grid, train_f1, label="train")
        plt.xlabel(xlabel)
        plt.legend()
        plt.show()

# %%
def Anv(RFC,X_train, y_train, X_test, y_test):
    
    #print('я обучаюсь')

    RFC.fit(X_train, y_train)
    
    #print('я обучился')
    
    train_ans = RFC.predict(X_train)
    test_ans = RFC.predict(X_test)
    temp_train_acc = accuracy_score(y_train, train_ans)
    temp_train_f1 = classification_report(y_train, train_ans, output_dict=True, zero_division=0)['0']['f1-score']
    temp_test_acc = accuracy_score(y_test, test_ans)
    temp_test_f1 = classification_report(y_test, test_ans, output_dict=True, zero_division=0)['0']['f1-score']
    return temp_train_acc, temp_test_acc, temp_train_f1, temp_test_f1

# %%
train_acc = []
test_acc = []
train_f1 = []
test_f1 = []
trees_grid = [5, 10, 15, 30, 50, 100, 150, 200]
for ntrees in tqdm(trees_grid):
    RFC = RandomForestClassifier(n_estimators=ntrees, random_state=42)
    temp_train_acc, temp_test_acc, temp_train_f1, temp_test_f1 = Anv(RFC,X_train_rf, y_train_rf, X_test_rf, y_test_rf)
    train_acc.append(temp_train_acc)
    test_acc.append(temp_test_acc)
    train_f1.append(temp_train_f1)
    test_f1.append(temp_test_f1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=8.0), HTML(value='')))

# %%
visualize(test_acc, train_acc, test_f1, train_f1, trees_grid, "trees number")
# Out:
# Best accuracy_store is 0.8654795714193507 with 200 trees number
# Лучший f1_score  0.8692313725490196 with 200 trees number

# %%
train_acc = []
test_acc = []
train_f1 = []
test_f1 = []
trees_grid = [1, 3, 4, 5, 10]
for ntrees in tqdm(trees_grid):
    RFC = RandomForestClassifier(n_estimators=100, random_state=42, max_features=ntrees)
    temp_train_acc, temp_test_acc, temp_train_f1, temp_test_f1 = Anv(RFC,X_train_rf, y_train_rf, X_test_rf, y_test_rf)
    train_acc.append(temp_train_acc)
    test_acc.append(temp_test_acc)
    train_f1.append(temp_train_f1)
    test_f1.append(temp_test_f1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
visualize(test_acc, train_acc, test_f1, train_f1, trees_grid, "max_features")
# Out:
# Best accuracy_store is 0.864769573355709 with 4 max_features
# Лучший f1_score  0.8685944549627417 with 3 max_features

# %%
train_acc = []
test_acc = []
train_f1 = []
test_f1 = []
trees_grid = [1, 3, 5, 7, 10]
for ntrees in tqdm(trees_grid):
    RFC = RandomForestClassifier(n_estimators=100, random_state=42, min_samples_leaf=ntrees, max_features=3)
    temp_train_acc, temp_test_acc, temp_train_f1, temp_test_f1 = Anv(RFC,X_train_rf, y_train_rf, X_test_rf, y_test_rf)
    train_acc.append(temp_train_acc)
    test_acc.append(temp_test_acc)
    train_f1.append(temp_train_f1)
    test_f1.append(temp_test_f1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
visualize(test_acc, train_acc, test_f1, train_f1, trees_grid, "min_samples_leaf")
# Out:
# Best accuracy_store is 0.8651649131866004 with 3 min_samples_leaf
# Лучший f1_score  0.8688865805617075 with 5 min_samples_leaf

# %%
train_acc = []
test_acc = []
train_f1 = []
test_f1 = []
trees_grid = [2, 3, 5, 7, 10]
for ntrees in tqdm(trees_grid):
    RFC = RandomForestClassifier(n_estimators=100, random_state=42, min_samples_split=ntrees, max_features=3)
    temp_train_acc, temp_test_acc, temp_train_f1, temp_test_f1 = Anv(RFC,X_train_rf, y_train_rf, X_test_rf, y_test_rf)
    train_acc.append(temp_train_acc)
    test_acc.append(temp_test_acc)
    train_f1.append(temp_train_f1)
    test_f1.append(temp_test_f1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
visualize(test_acc, train_acc, test_f1, train_f1, trees_grid, "min_samples_split")
# Out:
# Best accuracy_store is 0.8649067320725489 with 10 min_samples_split
# Лучший f1_score  0.8683005867639887 with 10 min_samples_split

# %%
def CV(RFC, X, y): #в данном случае не используется, чтобы уменьшить время работы
    temp_train_acc = []
    temp_test_acc = []
    temp_train_f1 = []
    temp_test_f1 = []

    for train_index, test_index in skf.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        RFC.fit(X_train, y_train)
        train_ans = RFC.predict(X_train)
        test_ans = RFC.predict(X_test)
        temp_train_acc.append(accuracy_score(y_train, train_ans)) 
        temp_train_f1.append(f1_score(y_train, train_ans, average="binary"))
        temp_test_acc.append(accuracy_score(y_test, test_ans))
        temp_test_f1.append(f1_score(y_test, test_ans, average="binary"))
    return temp_train_acc, temp_test_acc, temp_train_f1, temp_test_f1

# %%
X_rf, y_rf = X2[index], y2[index]
count = np.min(((y_rf==0).sum(), (y_rf==1).sum()))
ind0 = np.random.choice((y_rf==0).sum(), size=count, replace=False)
ind1 = np.random.choice((y_rf==1).sum(), size=count, replace=False)

robust = RobustScaler()
robust.fit_transform(X2_train_not_scaling)
#print(X[y==1].shape, len(y[y==2][ind2]), np.sum(y[y==2][ind2]))
#print((X[y==2][ind2] == X[y==1][ind1][23], g((X[y==2][ind2] == X[y==1][ind1][23])))
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.999, random_state = 42, stratify=y)
X_rf, y_rf = robust.transform(np.concatenate((X_rf[y_rf==0][ind0], X_rf[y_rf==1][ind1]))), np.concatenate((y_rf[y_rf==0][ind0], y_rf[y_rf==1][ind1]))
print(X_rf, y_rf)

# %% [markdown]
# # Проверка точности по подклассам звезд

# %%
df_sub = pd.read_pickle('df_done_sub.pkl') #выборка с уже объединеными подклассами звезд 
df_sub.head()
# Out:
#                  objID         ra       dec         z      zErr   class  \
# 0  1237679341106758387  37.470142 -5.554778  0.785255  0.000138  GALAXY
# 1  1237679341106757929  37.431501 -5.600435  1.285837  3.473993     QSO
# 2  1237679341106758149  37.388988 -5.556329  0.779955  0.000054  GALAXY
# 3  1237679440426172681  37.327114 -5.485252  0.714883  0.000028  GALAXY
# 4  1237679341106692861  37.315868 -5.519308  0.316563  0.000031  GALAXY
#
#   subClass  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  cModelMag_u  \
# 0      NaN  23.38412  23.00183  22.67571  21.95927  21.39581     20.01718
# 1      NaN  22.52914  23.78679  23.21358  22.17294  21.80350     21.23949
# 2      NaN  25.44541  23.13342  23.57675  24.34838  22.31492     20.38550
# 3      NaN  25.43466  23.13782  23.31316  22.53812  22.60905     25.45580
# 4      NaN  23.17536  21.34756  20.35171  20.05924  19.64511     21.14052
#
#    cModelMag_g  cModelMag_r  cModelMag_i  cModelMag_z
# 0     21.90474     21.99600     21.05722     20.29795
# 1     20.26025     22.12909     21.14929     20.66354
# 2     22.09762     23.74675     24.19759     20.62257
# 3     22.96513     23.37321     22.59266     22.64923
# 4     20.62957     19.60872     19.07587     18.90757

# %%
labels = {'STAR':0, 'GALAXY':1, 'QSO':1}
df_sub.replace({'class':labels}, inplace = True)
df_sub.head()
# Out:
#                  objID         ra       dec         z      zErr  class  \
# 0  1237679341106758387  37.470142 -5.554778  0.785255  0.000138      1
# 1  1237679341106757929  37.431501 -5.600435  1.285837  3.473993      1
# 2  1237679341106758149  37.388988 -5.556329  0.779955  0.000054      1
# 3  1237679440426172681  37.327114 -5.485252  0.714883  0.000028      1
# 4  1237679341106692861  37.315868 -5.519308  0.316563  0.000031      1
#
#   subClass  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  cModelMag_u  \
# 0      NaN  23.38412  23.00183  22.67571  21.95927  21.39581     20.01718
# 1      NaN  22.52914  23.78679  23.21358  22.17294  21.80350     21.23949
# 2      NaN  25.44541  23.13342  23.57675  24.34838  22.31492     20.38550
# 3      NaN  25.43466  23.13782  23.31316  22.53812  22.60905     25.45580
# 4      NaN  23.17536  21.34756  20.35171  20.05924  19.64511     21.14052
#
#    cModelMag_g  cModelMag_r  cModelMag_i  cModelMag_z
# 0     21.90474     21.99600     21.05722     20.29795
# 1     20.26025     22.12909     21.14929     20.66354
# 2     22.09762     23.74675     24.19759     20.62257
# 3     22.96513     23.37321     22.59266     22.64923
# 4     20.62957     19.60872     19.07587     18.90757

# %%
df_sub[df_sub['class']==0]['subClass'].value_counts()
# Out:
# F     367866
# M     179953
# K     152959
# A      95455
# G      93480
# WD     34472
# C      14451
# OB     13731
# LT      7996
# Name: subClass, dtype: int64

# %%
X_sub = df_sub.drop(['class','subClass', 'objID', 'z', 'zErr', 'ra', 'dec'], axis = 1).values
y_sub = df_sub['class'].values
sub = df_sub['subClass']
robust = RobustScaler()
robust.fit_transform(X2_train_not_scaling)
X_sub_test_not_scaling = X_sub.copy()
X_sub = robust.transform(X_sub)

# %%
for i in df_sub[df_sub['class']==0]['subClass'].unique():
    print_plot2(rf2, X_sub[sub == i], y_sub[sub == i], X_sub_test_not_scaling[sub == i], i, 0.85)
# Out:
# [0 0 0 ... 1 1 1]
# 0.01 0.6196630160067397
# 0.02 0.6761931034482759
# 0.03 0.7144578547412201
# 0.04 0.7435072815533981
# 0.05 0.7762265824656261
# 0.06 0.785059705637323
# 0.07 0.8059400293930553
# 0.08 0.8115929223088648
# 0.09 0.8276483575902311
# 0.1 0.8365255414607483
# 0.11 0.8405034324942792
# 0.12 0.8477769056743155
# 0.13 0.8549374810813328
# [0 0 0 ... 1 1 1]
# 0.01 0.6174209360102061
# 0.02 0.673077978881101
# 0.03 0.7124590735610361
# 0.22 0.5637704721273554
# 0.23 0.5759529085252579
# 0.24 0.5797385842045314
# 0.25 0.5880363244433233
# 0.26 0.5964588970794066
# 0.27 0.6078197355229866
# 0.28 0.6157754334909664
# 0.29 0.6190662286433082
# 0.3 0.6324102255789777
# 0.31 0.6409998471960475
# 0.32 0.6455031212269119
# 0.33 0.6586185094444006
# 0.34 0.6669298609531202
# 0.35 0.6712546892289424
# 0.36 0.6851928832723645
# 0.37 0.6947304578408418
# 0.38 0.6993979419006817
# 0.39 0.7085929575423852
# [0.7022097222746548, 0.717162864845465, 0.7171442227460892, 0.7012600387704238, 0.7032609349101246, 0.7025318483240254, 0.7022497482654455, 0.7095228016881839, 0.7066974326702328, 0.7085929575423852]
# [0.6985004193318229, 0.710162655382174, 0.7103309929789368, 0.6948665354087632, 0.6892903138915311, 0.6735947578580935, 0.6488784093805761, 0.6529076161671707, 0.6394908623071488, 0.6575497196337085]
# [0.05, 0.09, 0.09, 0.07, 0.13, 0.21, 0.28, 0.3, 0.33, 0.39]

# %%
X2_test[:2], y2_test[:2]
# Out:
# (array([[-1.09682435, -1.01115869, -0.9878451 , -0.97062823, -0.89092233,
#          -0.98010301, -0.91397802, -0.78171679, -0.69409357, -0.61793084],
#         [ 0.00406144,  0.23171277,  0.51960119,  0.82358814,  0.90097769,
#           0.39661202,  0.33176421,  0.60225283,  0.91019281,  1.03004431]]),
#  array([0, 0]))

# %%
s = rf2.predict(X2_test)
sp = rf2.predict_proba(X2_test)
yt = y2_test

# %%
s[:2]
# Out:
# array([0, 0])

# %%
s2 = rf2.predict_proba(X2_test[:2])
s22 = rf2.predict(X2_test[:2])
s22
# Out:
# array([0, 0])

# %%
from sklearn.metrics import precision_score, recall_score
print(precision_score(y2_test, s, average='binary'))
print(recall_score(y2_test, s, average='binary'))
# Out:
# 0.9565815541123986
# 0.9357912561776722

# %%
pr = (((sp[:, 1] > (1- 0.5))*1 == yt)[sp[:, 0] >= 0.5].sum())/(((sp[:, 1] > (1- 0.5))*1 == yt).sum())
pr
# Out:
# 0.5057396512348946

# %%
confusion_matrix(yt, s)
# Out:
# array([[735658,  32633],
#        [ 49331, 718960]])

# %%
t = 0.5
pred = (sp[:, 1] > (1- t))*1
TP = (pred == yt)[sp[:, 0] >= t].sum()
FN = (pred != yt)[sp[:, 0] >= t].sum()
FP = (pred != yt)[sp[:, 1] >= t].sum()
TN = (pred == yt)[sp[:, 1] >= t].sum()
print(TP, FP, TN, FN)
print(THRESHOLD (yt, sp, 0.95))
TP/(TP+FP), TP/(TP+FN)
# Out:
# 735658 33330 719625 49331
# 0.01 0.6178026400515132
# 0.02 0.6732340153542505
# 0.03 0.7117568523028067
# 0.04 0.7399538088374192
# 0.05 0.7708983947620781
# 0.06 0.7790430735167293
# 0.07 0.7999882641283653
# 0.08 0.8057195098648824
# 0.09 0.8206795900202235
# 0.1 0.8292034040497355
# 0.11 0.8331144425283146
# 0.12 0.8401848502670906
# 0.13 0.8464628329373237
# 0.14 0.8550107904648053
# 0.15 0.8600733935815705
# 0.16 0.8625353545560966
# 0.17 0.869450279590682
# 0.18 0.8736758822269364
# 0.19 0.8757283167713195
# 0.2 0.881487151626972
# 0.21 0.8833741487079019
# 0.22 0.8869931987135551
# 0.23 0.8921287853946341
# 0.24 0.8937418367286633
# 0.25 0.8969574383226027
# 0.26 0.9000542334900741
# 0.27 0.9042873310219486
# 0.28 0.9072883553143931
# 0.29 0.908613924188013
# 0.3 0.9128241515658734
# 0.31 0.9155759879418619
# 0.32 0.9169619691112626
# 0.33 0.9209817052749607
# 0.34 0.923539486109897
# 0.35 0.9247478273311016
# 0.36 0.9284797497975538
# 0.37 0.9308755358931761
# 0.38 0.9320752176644825
# 0.39 0.9343806144560828
# 0.4 0.9378018533797516
# 0.41 0.9389290758784403
# 0.42 0.9410672900764806
# 0.43 0.9441866376872382
# 0.44 0.9452689694512636
# 0.45 0.947157141068458
# 0.46 0.9500725652123656
# 0.46
# (0.9566573210505236, 0.9371570811820293)

# %%
def THRESHOLD (yt, sp, p):
    t = 0
    maxt = np.zeros(2) #maxt[0] = pr max, maxt[1] = THRESHOLD max
    for THRESHOLD in np.arange(0.01, 1.01, 0.01).astype('float32'):
        #print(yt.shape)
        pred = (sp[:, 1] > (1 - THRESHOLD))*1
        #print(len(pred))
        TP = (pred == yt)[sp[:, 0] >= THRESHOLD].sum()
        FN = (pred != yt)[sp[:, 0] >= THRESHOLD].sum()
        FP = (pred != yt)[sp[:, 1] >= THRESHOLD].sum()
        TN = (pred == yt)[sp[:, 1] >= THRESHOLD].sum()
        pr = TP/(TP+FP)
        print(THRESHOLD, pr)
        if pr >= p and pr!=1.0:
            t = THRESHOLD
            break
        #if pr > maxt[0] and pr!=1.0:
        #    maxt[0] = pr
        #    maxt[1] = THRESHOLD
    return t

# %%
def precis(yt, sp, THRESHOLD):
        pred = (sp[:, 1] > (1 - THRESHOLD))*1
        TP = (pred == yt)[sp[:, 0] >= THRESHOLD].sum()
        FN = (pred != yt)[sp[:, 0] >= THRESHOLD].sum()
        FP = (pred != yt)[sp[:, 1] >= THRESHOLD].sum()
        TN = (pred == yt)[sp[:, 1] >= THRESHOLD].sum()
        return TP/(TP+FP)

# %%
def recal(yt, sp, THRESHOLD):
        pred = (sp[:, 1] > (1 - THRESHOLD))*1
        TP = (pred == yt)[sp[:, 0] >= THRESHOLD].sum()
        FN = (pred != yt)[sp[:, 0] >= THRESHOLD].sum()
        FP = (pred != yt)[sp[:, 1] >= THRESHOLD].sum()
        TN = (pred == yt)[sp[:, 1] >= THRESHOLD].sum()
        return TP/(TP+FN)

# %%
def print_plot2(ml, X_sub, y_sub, X_sub_test_not_scaling, name, prec=0.8):
    
    X_test_not_scaling = X_sub_test_not_scaling[X_sub_test_not_scaling[:,7].argsort()]
    X_test = X_sub[X_sub_test_not_scaling[:,7].argsort()]
    y_test = y_sub[X_sub_test_not_scaling[:,7].argsort()]
    
    #shift = 1000
    #n = len(y_test)//shift
    n = 10
    shift = len(y_test)//n
    precision = []
    recall = []
    f1 = []
    r_mean = []
    threshold = []
    #y_pred_all = ml.predict(X_test)
    y_pred_all_proba = ml.predict_proba(X_test)

    for i in range(0, n):
            ind = np.random.choice((y2_test==1).sum(), size=shift, replace=False)
            
            yt = np.concatenate((y_test[i*shift : (i+1) * shift], y2_test[y2_test==1][ind]))
            print(yt)
            #y = y_pred_all[i*shift : (i+1) * shift]
            yp = np.concatenate((y_pred_all_proba[i*shift : (i+1) * shift], ml.predict_proba(X2_test[y2_test==1][ind])))
            #print(yp)
            #h = classification_report(y_test[i*shift : (i+1) * shift], y_pred_all[i*shift : (i+1) * shift], output_dict=True, zero_division=0)
            #precision.append(h['0']['precision'])
            p = THRESHOLD(yt, yp, prec)
            if p > 0:
                recall.append(recal(yt, yp, p))
                precision.append(precis(yt, yp, p))
                threshold.append(p)
                #f1.append(h['0']['f1-score'])
                r_mean.append(X_test_not_scaling[i*shift : (i+1) * shift][:,7].mean())
            
    plt.title('Зависимость recall от признкака cModelMag_r:'+name)
    plt.plot(r_mean, recall, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
    plt.figure(figsize = (5,4))
    
    print(precision)
    print(recall)
    print(threshold)

# %%
print_plot2(rf2, X_sub[sub == 'OB'], y_sub[sub == 'OB'], X_sub_test_not_scaling[sub == 'OB'], 'OB', 0.92)
# Out:
# [0 0 0 ... 1 1 1]
# 0.01 0.6267767079321412
# 0.02 0.6855851330989452
# 0.03 0.718421052631579
# 0.04 0.7495881383855024
# 0.05 0.7789834380354084
# 0.06 0.788316946211683
# 0.07 0.806872037914692
# 0.08 0.8111971411554497
# 0.09 0.8263509411050395
# 0.1 0.8338442673206622
# 0.11 0.8369230769230769
# 0.12 0.8430521091811415
# 0.13 0.8514106583072101
# 0.14 0.8611287254280279
# 0.15 0.8677316293929712
# 0.16 0.8710711994868505
# 0.17 0.8760490639122014
# 0.18 0.8805194805194805
# 0.19 0.8810143042912874
# 0.2 0.8889618922470434
# 0.21 0.8889618922470434
# 0.22 0.8918918918918919
# 0.23 0.8982712765957447
# 0.24 0.8994673768308922
# 0.25 0.9018036072144289
# 0.26 0.9042196918955124
# 0.27 0.9071332436069987
# 0.28 0.9101958136394328
# 0.29 0.9107505070993914
# 0.3 0.9131614654002713
# 0.31 0.9155313351498637
# 0.32 0.9167803547066848
# 0.33 0.9217570350034318
# [0 0 0 ... 1 1 1]
# 0.01 0.6199546485260771
# 0.02 0.6762376237623763
# 0.03 0.7159389794844818
# 0.04 0.7428884026258206
# 0.05 0.773531089560753
# 0.06 0.7809798270893372
# 0.07 0.8011834319526627
# 0.08 0.805952380952381
# 0.09 0.8256097560975609
# 0.1 0.8315918869084205
# 0.11 0.8345679012345679
# 0.12 0.8413192283758556
# 0.13 0.848180677540778
# 0.14 0.8566899175649968
# 0.15 0.8616071428571429
# 0.16 0.8631713554987213
# 0.17 0.8697614442295294
# 0.18 0.874189364461738
# 0.19 0.8776041666666666
# 0.2 0.881544502617801
# 0.21 0.8850197109067017
# 0.22 0.8878627968337731
# 0.23 0.8924302788844621
# 0.24 0.892358803986711
# 0.79 0.5570469798657718
# 0.8 0.5487364620938628
# 0.81 0.5138339920948617
# 0.82 0.5061728395061729
# 0.83 0.4772727272727273
# 0.84 0.4577114427860697
# 0.85 0.4161849710982659
# 0.86 0.3987341772151899
# 0.87 0.3783783783783784
# 0.88 0.375
# 0.89 0.38095238095238093
# 0.9 0.3805309734513274
# 0.91 0.39361702127659576
# 0.92 0.37037037037037035
# 0.93 0.375
# 0.94 0.36764705882352944
# 0.95 0.3448275862068966
# 0.96 0.3333333333333333
# 0.97 0.5416666666666666
# 0.98 0.6666666666666666
# 0.99 0.8571428571428571
# 1.0 1.0
# [0.9217570350034318, 0.92, 0.9214186369958275, 0.9218045112781955, 0.9231348907309721, 0.9202551834130781, 0.9210740439381611, 0.9211538461538461]
# [0.9136054421768708, 0.9099590723055935, 0.9156876295784382, 0.9526029526029526, 0.9365443425076453, 0.9382113821138212, 0.9472803347280335, 0.9419862340216323]
# [0.33, 0.34, 0.33, 0.54, 0.55, 0.58, 0.59, 0.64]

# %%
def print_plot3(ml, X_sub, y_sub, X_sub_test_not_scaling, name):   #функция для построения общего графика для всех подклассов
    
    X_test_not_scaling = X_sub_test_not_scaling[X_sub_test_not_scaling[:,7].argsort()]
    X_test = X_sub[X_sub_test_not_scaling[:,7].argsort()]
    y_test = y_sub[X_sub_test_not_scaling[:,7].argsort()]
    
    #shift = 1000
    #n = len(y_test)//shift
    n = 30
    shift = len(y_test)//n
    precision = []
    recall = []
    f1 = []
    r_mean = []
    
    shift1 = []
    
    y_pred_all = ml.predict(X_test)

    for i in range(0, n):
            #h = classification_report(y_test[i*shift : (i+1) * shift], y_pred_all[i*shift : (i+1) * shift], output_dict=True, zero_division=0)
            #precision.append(h['0']['precision'])
            recall.append(h['1']['recall'])
            #f1.append(h['0']['f1-score'])
            r_mean.append(X_test_not_scaling[i*shift : (i+1) * shift][:,7].mean())
            #shift1.append(np.log10(len(y_test[i*shift : (i+1) * shift])))
            
    return r_mean, recall

# %%
subclass = df_sub[df_sub['class']==0]['subClass'].unique()[df_sub[df_sub['class']==0]['subClass'].value_counts()[df_sub[df_sub['class']==0]['subClass'].unique()].argsort()]

# %%
from itertools import cycle
# setup plot details
colors = cycle(['blue', 'g', 'gold', 'cornflowerblue', 'lime', 'r', 'turquoise', 'magenta'])
#n_classes = 9

plt.figure(figsize=(10, 10))

lines = []
labels = []

for i, color in zip(subclass[1:][::-1], colors):
    x, y, shift = print_plot3(rf2, X_sub[sub == i], y_sub[sub == i], X_sub_test_not_scaling[sub == i], i)
    #print(x, y)
    l, = plt.plot(x, y, color=color, lw=2)
    lines.append(l)
    labels.append('Recall for class '+ i + ' ' + str(shift))

fig = plt.gcf()
fig.subplots_adjust(bottom=0.25)
plt.xlim([15, 23])
#plt.ylim([0.4, 1.05])
plt.xlabel('cModelMag_r')
plt.ylabel('Recall')
#plt.title('Extension of Precision-Recall curve to multi-class')
plt.legend(lines, labels, loc=(0, -0.4), prop=dict(size=14))


plt.show()

# %%
# Out:
# 'jhgj5'
